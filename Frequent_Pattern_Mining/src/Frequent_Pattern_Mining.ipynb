# %% [markdown]
# # Data Preprocessing for Retail Dataset
# ### This notebook provides different methods for cleaning and preprocessing a retail dataset as well as finding rules with the apriori algorithm. You can choose different approaches based on your needs, such as filtering by date or maximizing the number of customers.

# %%
import pandas as pd

# Load dataset
df = pd.read_csv("../datasets/retail.csv")
print("Dataset Loaded.")
df.head()
# Out:
# Dataset Loaded.
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#            InvoiceDate  Price  Customer ID         Country
# 0  2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1  2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2  2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3  2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4  2009-12-01 07:45:00   1.25      13085.0  United Kingdom

# %% [markdown]
# ## Handling Missing Values
# ### One way of handing missing values is to simply remove all the rows which contain missing values.

# %%
df.dropna(inplace=True)

# %% [markdown]
# ### Since we would like to keep most of the data, we will apply some default values when the missing values are not that important, or when the entries can still be used for other feature extracting.

# %%
fill_na = {
    "Description": "No description available",
    "Country": "Unknown",
    "Customer ID": 0,
    "Quantity": 0,
    "InvoiceDate": df["InvoiceDate"].min()
}
df.fillna(fill_na, inplace=True)

# %% [markdown]
# ### When the Invoice or StockCode missing, we will discard the entries either way.

# %%
# Remove all transactions without Invoice and StockCode since these are important info
df.dropna(subset=["Invoice"], inplace=True)
df.dropna(subset=["StockCode"], inplace=True)

# %% [markdown]
# ### When the price is missing, we will search for products with the same StockCode and take the price of that product.

# %%
# Search for other products with same StockCode and copy price if found.
def fill_price(row):
    if pd.isna(row["Price"]):
        stock_price = df.loc[df["StockCode"] == row["StockCode"], "Price"].dropna().iloc[0] if not df.loc[df["StockCode"] == row["StockCode"], "Price"].dropna().empty else np.nan
        return stock_price
    return row["Price"]

df["Price"] = df.apply(fill_price, axis=1)

# %% [markdown]
# ### When the quantity of a transaction is negative, we assume that the product is returned and thus we can remove the entries.

# %%
df = df.loc[df["Quantity"] > 0].copy()

# %% [markdown]
# ## Filtering Dataset
# ### A function is made such that you can choose on what to filter, and have the option to choose a random interval/selection

# %%
import numpy as np

# Prune dataset based on column, amount and randomness. If random = False, take the first N entries.
def prune_dataset(df, column, amount, random=False):
    df["InvoiceDate"] = pd.to_datetime(df["InvoiceDate"])

    # Filter by InvoiceDate
    if column == "InvoiceDate":
        if random:
            unique_dates = df["InvoiceDate"].dt.date.unique()
            selected_dates = np.random.choice(unique_dates, min(amount, len(unique_dates)), replace=False)
            df = df[df["InvoiceDate"].dt.date.isin(selected_dates)]
        else:
            earliest_date = df["InvoiceDate"].min()
            df = df[df["InvoiceDate"] < earliest_date + pd.Timedelta(days=amount)]

    # Filter by Customer ID
    elif column == "Customer ID":
        unique_customers = df["Customer ID"].unique()
        if random:
            selected_customers = np.random.choice(unique_customers, min(amount, len(unique_customers)), replace=False)
        else:
            selected_customers = df["Customer ID"].value_counts().nsmallest(amount).index
        df = df[df["Customer ID"].isin(selected_customers)]

    # Filter by Invoice
    elif column == "Invoice":
        unique_invoices = df["Invoice"].unique()
        if random:
            selected_invoices = np.random.choice(unique_invoices, min(amount, len(unique_invoices)), replace=False)
        else:
            selected_invoices = df["Invoice"].value_counts().nsmallest(amount).index
        df = df[df["Invoice"].isin(selected_invoices)]

    return df

# %% [markdown]
# ### You can now for example say you want the 100 last days of data.

# %%
df = prune_dataset(df, "InvoiceDate", 100, False)

# %% [markdown]
# ### Or lets say say you want 30 random customers.

# %%
df = prune_dataset(df, "Customer ID", 30, True)

# %% [markdown]
# ## Feature Engineering
# ### We can add different categories to easily seperate products/transaction/customers that are have things in common. A logical category for a retail dataset is by differentiating all transactions based on there time of purchase in the day. We can split in Morning, Afternoon, Evening and Night. Additionally, we can add a category for each day of the week.

# %%
# Return moment of day based on hour
def categorize_time(hour):
    if 6 <= hour < 12:
        return "Morning"
    elif 12 <= hour < 18:
        return "Afternoon"
    elif 18 <= hour < 24:
        return "Evening"
    else:
        return "Night"

# Convert InvoiceDate to datetime format
df["InvoiceDate"] = pd.to_datetime(df["InvoiceDate"])

df["TimeOfDay"] = df["InvoiceDate"].dt.hour.apply(categorize_time)

# Add category for day of week, placing "Monday", "Tuesday", ...
df["DayOfWeek"] = df["InvoiceDate"].dt.day_name()

# %% [markdown]
# ### For the categorization of the price and quantity of transactions, we can use pandas qcut to evenly distribute the entries.

# %%
# For splitting up the price category, only look at the prices of the unique products, eliminating the case where 1 product is bought multiple times and overrules other products.
unique_prices = df.drop_duplicates(subset="StockCode")["Price"]
price_bins, price_edges = pd.qcut(unique_prices, q=3, labels=["Cheap", "Mid-Range", "Expensive"], duplicates="drop", retbins=True)

# Split up prices in "Cheap', "Mid-range" and "Expensive
df["PriceCategory"] = pd.cut(df["Price"], bins=price_edges, labels=["Cheap", "Mid-Range", "Expensive"], include_lowest=True)
print(price_edges)

# Split up quantities in "Small', "Medium" and "Large"
df["QuantityCategory"], quantity_edges = pd.qcut(df["Quantity"], q=3, labels=["Small", "Medium", "Large"], duplicates="drop", retbins=True)
print(quantity_edges)
# Out:
# [  0.     1.65   3.9  647.19]
# [1.0000e+00 2.0000e+00 6.0000e+00 1.9152e+04]

# %% [markdown]
# ### We can create some plots to show the distribution of the entries and get a better view of the data.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.countplot(x="DayOfWeek", data=df, order=[
    "Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"
])
plt.title("Number of Transactions by Day of the Week")
plt.ylabel("Number of Transactions")
plt.xlabel("Day of the Week")
plt.show()

plt.figure(figsize=(8, 6))
sns.countplot(x="PriceCategory", data=df)
plt.title("Number of Transactions by Price Category")
plt.ylabel("Number of Transactions")
plt.xlabel("Price Category")
plt.show()

plt.figure(figsize=(8, 6))
sns.countplot(x="TimeOfDay", data=df, order=["Morning", "Afternoon", "Evening", "Night"])
plt.title("Number of Transactions by Time of Day")
plt.ylabel("Number of Transactions")
plt.xlabel("Time of Day")
plt.show()

plt.figure(figsize=(8, 6))
sns.countplot(x="QuantityCategory", data=df)
plt.title("Number of Transactions by Quantity Category")
plt.ylabel("Number of Transactions")
plt.xlabel("Quantity Category")
plt.show()

# %% [markdown]
# ## Mining Association Rules
# ### Before mining the rules in the dataset, I created a function that prints out the best rules in a clean format, showing the Support, Confidence and Lift, as well as the description if mining was done on stockcodes.

# %%
def display_association_rules(rules, mapping=None, top_n=100):
    # Function to convert StockCode to Description
    def map_item(item):
        if mapping is not None:
            return mapping.get(item, item)
        return item

    # Sort rules by highest confidence (considering the maximum confidence among ordered_statistics)
    sorted_rules = sorted(
        rules,
        key=lambda rule: max(stat.confidence for stat in rule.ordered_statistics),
        reverse=True
    )
    top_n = min(top_n, len(sorted_rules))

    # Print product association rules with descriptions
    print("\n--- ASSOCIATION RULES (Sorted by Confidence) ---\n")
    for rule in sorted_rules[:top_n]:
        # Convert StockCodes to Descriptions
        items = [map_item(x) for x in rule.items]
        print(f"Rule: {items} | Support: {rule.support:.4f}")
        for ordered_stat in rule.ordered_statistics:
            base = ', '.join(map_item(x) for x in ordered_stat.items_base)
            add = ', '.join(map_item(x) for x in ordered_stat.items_add)
            print(f"  {base} -> {add} | Confidence: {ordered_stat.confidence:.4f} | Lift: {ordered_stat.lift:.4f}")
        print("-" * 50)

    # Prepare data for scatter plot using the same top_n rules.
    rules_list = []
    for rule in sorted_rules[:top_n]:
        for ordered_stat in rule.ordered_statistics:
            base = ', '.join(map_item(x) for x in ordered_stat.items_base)
            add = ', '.join(map_item(x) for x in ordered_stat.items_add)
            rule_str = f""
            rules_list.append({
                'rule': rule_str,
                'support': rule.support,
                'confidence': ordered_stat.confidence,
                'lift': ordered_stat.lift
            })

    rules_df = pd.DataFrame(rules_list)

    if rules_df.empty:
        print("No rules extracted to plot.")
        return

    # Create the scatter plot
    plt.figure(figsize=(10, 6))
    # Scale marker sizes based on lift (adjust factor as needed)
    sizes = rules_df['lift'] * 10
    scatter = plt.scatter(rules_df['support'], rules_df['confidence'],
                          s=sizes, c=rules_df['lift'], cmap='viridis', alpha=0.7)

    plt.xlabel('Support')
    plt.ylabel('Confidence')
    plt.title(f'Scatter Plot of Association Rules')

    # Add a colorbar to show lift values
    cbar = plt.colorbar(scatter)
    cbar.set_label('Lift')

    # Annotate each point with the rule text
    for i, row in rules_df.iterrows():
        plt.annotate(row['rule'], (row['support'], row['confidence']),
                     fontsize=8, alpha=0.8, textcoords="offset points", xytext=(5,5))

    plt.show()

# %% [markdown]
# ### The most common case of pattern mining is to group the transactions where the invoice is the same, and get rules between different products.

# %%
from apyori import apriori

# Used for mapping StockCodes to Descriptions
stockcode_to_description = df.set_index("StockCode")["Description"].to_dict()

product_transactions = df.groupby("Invoice")["StockCode"].apply(list).tolist()

# Run Apriori for Product-Product category association
product_rules = list(apriori(
    product_transactions,
    min_support=0.015,
    min_confidence=0.5,
    min_lift=1.1,
    min_length=2
))

display_association_rules(product_rules, stockcode_to_description)
# Out:
# --- ASSOCIATION RULES (Sorted by Confidence) ---
#
# Rule: ['PINK FELT EASTER EGG BASKET', 'BLUE FELT EASTER EGG BASKET'] | Support: 0.0168
#   BLUE FELT EASTER EGG BASKET -> PINK FELT EASTER EGG BASKET | Confidence: 0.8737 | Lift: 35.1818
#   PINK FELT EASTER EGG BASKET -> BLUE FELT EASTER EGG BASKET | Confidence: 0.6748 | Lift: 35.1818
# --------------------------------------------------
# Rule: ['SET/10 PINK SPOTTY PARTY CANDLES', 'SET/10 BLUE SPOTTY PARTY CANDLES'] | Support: 0.0176
#   SET/10 PINK SPOTTY PARTY CANDLES -> SET/10 BLUE SPOTTY PARTY CANDLES | Confidence: 0.6850 | Lift: 32.9417
#   SET/10 BLUE SPOTTY PARTY CANDLES -> SET/10 PINK SPOTTY PARTY CANDLES | Confidence: 0.8447 | Lift: 32.9417
# --------------------------------------------------
# Rule: ['RED HANGING HEART T-LIGHT HOLDER', 'WHITE HANGING HEART T-LIGHT HOLDER'] | Support: 0.0507
#   RED HANGING HEART T-LIGHT HOLDER -> WHITE HANGING HEART T-LIGHT HOLDER | Confidence: 0.7994 | Lift: 4.6145
# --------------------------------------------------
# Rule: ['TOILET METAL SIGN', 'BATHROOM METAL SIGN'] | Support: 0.0176
#   BATHROOM METAL SIGN -> TOILET METAL SIGN | Confidence: 0.5058 | Lift: 22.1708
#   TOILET METAL SIGN -> BATHROOM METAL SIGN | Confidence: 0.7699 | Lift: 22.1708
# --------------------------------------------------
# Rule: ['60 TEATIME FAIRY CAKE CASES', 'PACK OF 72 RETRO SPOT CAKE CASES', 'PACK OF 60 PINK PAISLEY CAKE CASES'] | Support: 0.0208
#   PACK OF 72 RETRO SPOT CAKE CASES, PACK OF 60 PINK PAISLEY CAKE CASES -> 60 TEATIME FAIRY CAKE CASES | Confidence: 0.6319 | Lift: 10.3980
#   60 TEATIME FAIRY CAKE CASES, PACK OF 72 RETRO SPOT CAKE CASES -> PACK OF 60 PINK PAISLEY CAKE CASES | Confidence: 0.5598 | Lift: 11.0904
#   60 TEATIME FAIRY CAKE CASES, PACK OF 60 PINK PAISLEY CAKE CASES -> PACK OF 72 RETRO SPOT CAKE CASES | Confidence: 0.7687 | Lift: 8.7521
# --------------------------------------------------
# Rule: ['60 TEATIME FAIRY CAKE CASES', 'PACK OF 72 RETRO SPOT CAKE CASES', '72 SWEETHEART FAIRY CAKE CASES'] | Support: 0.0194
#   60 TEATIME FAIRY CAKE CASES, PACK OF 72 RETRO SPOT CAKE CASES -> 72 SWEETHEART FAIRY CAKE CASES | Confidence: 0.5217 | Lift: 9.4658
#   PACK OF 72 RETRO SPOT CAKE CASES, 72 SWEETHEART FAIRY CAKE CASES -> 60 TEATIME FAIRY CAKE CASES | Confidence: 0.6234 | Lift: 10.2578
#   60 TEATIME FAIRY CAKE CASES, 72 SWEETHEART FAIRY CAKE CASES -> PACK OF 72 RETRO SPOT CAKE CASES | Confidence: 0.7680 | Lift: 8.7446
# --------------------------------------------------
# Rule: ['60 TEATIME FAIRY CAKE CASES', 'PACK OF 60 DINOSAUR CAKE CASES', 'PACK OF 72 RETRO SPOT CAKE CASES'] | Support: 0.0164
#   PACK OF 60 DINOSAUR CAKE CASES, PACK OF 72 RETRO SPOT CAKE CASES -> 60 TEATIME FAIRY CAKE CASES | Confidence: 0.7168 | Lift: 11.7953
#   60 TEATIME FAIRY CAKE CASES, PACK OF 60 DINOSAUR CAKE CASES -> PACK OF 72 RETRO SPOT CAKE CASES | Confidence: 0.7642 | Lift: 8.7008
# --------------------------------------------------
# Rule: ['TOY TIDY PINK RETROSPOT  ', 'TOY TIDY SPACEBOY  '] | Support: 0.0153
#   TOY TIDY SPACEBOY   -> TOY TIDY PINK RETROSPOT   | Confidence: 0.7451 | Lift: 25.8075
#   TOY TIDY PINK RETROSPOT   -> TOY TIDY SPACEBOY   | Confidence: 0.5315 | Lift: 25.8075
# --------------------------------------------------
# Rule: ['PINK DOUGHNUT TRINKET POT ', 'STRAWBERRY CERAMIC TRINKET BOX'] | Support: 0.0196
#   PINK DOUGHNUT TRINKET POT  -> STRAWBERRY CERAMIC TRINKET BOX | Confidence: 0.7239 | Lift: 8.3771
# --------------------------------------------------
# Rule: ['PACK OF 72 RETRO SPOT CAKE CASES', 'PACK OF 60 PINK PAISLEY CAKE CASES', '72 SWEETHEART FAIRY CAKE CASES'] | Support: 0.0162
#   PACK OF 72 RETRO SPOT CAKE CASES, 72 SWEETHEART FAIRY CAKE CASES -> PACK OF 60 PINK PAISLEY CAKE CASES | Confidence: 0.5195 | Lift: 10.2919
#   PACK OF 60 PINK PAISLEY CAKE CASES, 72 SWEETHEART FAIRY CAKE CASES -> PACK OF 72 RETRO SPOT CAKE CASES | Confidence: 0.7143 | Lift: 8.1330
# --------------------------------------------------
# Rule: ['PACK OF 72 RETRO SPOT CAKE CASES', 'PACK OF 72 SKULL CAKE CASES'] | Support: 0.0242
#   PACK OF 72 SKULL CAKE CASES -> PACK OF 72 RETRO SPOT CAKE CASES | Confidence: 0.7018 | Lift: 7.9903
# --------------------------------------------------
# Rule: ['JUMBO BAG STRAWBERRY', 'JUMBO BAG RED WHITE SPOTTY '] | Support: 0.0256
#   JUMBO BAG STRAWBERRY -> JUMBO BAG RED WHITE SPOTTY  | Confidence: 0.6940 | Lift: 8.3430
# --------------------------------------------------
# Rule: ['RED/WHITE DOTS RUFFLED UMBRELLA', 'BLACK/BLUE DOTS RUFFLED UMBRELLA'] | Support: 0.0202
#   BLACK/BLUE DOTS RUFFLED UMBRELLA -> RED/WHITE DOTS RUFFLED UMBRELLA | Confidence: 0.6897 | Lift: 18.4641
#   RED/WHITE DOTS RUFFLED UMBRELLA -> BLACK/BLUE DOTS RUFFLED UMBRELLA | Confidence: 0.5405 | Lift: 18.4641
# --------------------------------------------------
# Rule: ['PACK OF 60 DINOSAUR CAKE CASES', 'PACK OF 72 RETRO SPOT CAKE CASES'] | Support: 0.0228
#   PACK OF 60 DINOSAUR CAKE CASES -> PACK OF 72 RETRO SPOT CAKE CASES | Confidence: 0.6807 | Lift: 7.7509
# --------------------------------------------------
# Rule: ['PINK FELT EASTER EGG BASKET', 'CREAM FELT EASTER EGG BASKET'] | Support: 0.0153
#   CREAM FELT EASTER EGG BASKET -> PINK FELT EASTER EGG BASKET | Confidence: 0.6786 | Lift: 27.3249
#   PINK FELT EASTER EGG BASKET -> CREAM FELT EASTER EGG BASKET | Confidence: 0.6179 | Lift: 27.3249
# --------------------------------------------------
# Rule: ['EDWARDIAN PARASOL RED', 'EDWARDIAN PARASOL BLACK'] | Support: 0.0166
#   EDWARDIAN PARASOL BLACK -> EDWARDIAN PARASOL RED | Confidence: 0.5000 | Lift: 20.2992
#   EDWARDIAN PARASOL RED -> EDWARDIAN PARASOL BLACK | Confidence: 0.6721 | Lift: 20.2992
# --------------------------------------------------
# Rule: ['WHITE CHERRY LIGHTS', 'LIGHT PINK CHERRY LIGHTS'] | Support: 0.0170
#   LIGHT PINK CHERRY LIGHTS -> WHITE CHERRY LIGHTS | Confidence: 0.6720 | Lift: 12.4195
# --------------------------------------------------
# Rule: ['60 TEATIME FAIRY CAKE CASES', 'PACK OF 60 PINK PAISLEY CAKE CASES', '72 SWEETHEART FAIRY CAKE CASES'] | Support: 0.0151
#   60 TEATIME FAIRY CAKE CASES, PACK OF 60 PINK PAISLEY CAKE CASES -> 72 SWEETHEART FAIRY CAKE CASES | Confidence: 0.5597 | Lift: 10.1546
#   PACK OF 60 PINK PAISLEY CAKE CASES, 72 SWEETHEART FAIRY CAKE CASES -> 60 TEATIME FAIRY CAKE CASES | Confidence: 0.6696 | Lift: 11.0191
#   60 TEATIME FAIRY CAKE CASES, 72 SWEETHEART FAIRY CAKE CASES -> PACK OF 60 PINK PAISLEY CAKE CASES | Confidence: 0.6000 | Lift: 11.8872
# --------------------------------------------------
# Rule: ['RETRO SPOT SMALL MILK JUG', 'RETRO SPOT SUGAR JAM BOWL'] | Support: 0.0212
#   RETRO SPOT SUGAR JAM BOWL -> RETRO SPOT SMALL MILK JUG | Confidence: 0.6604 | Lift: 13.8595
# --------------------------------------------------
# Rule: ['60 TEATIME FAIRY CAKE CASES', 'PACK OF 72 RETRO SPOT CAKE CASES', 'WHITE HANGING HEART T-LIGHT HOLDER'] | Support: 0.0151
#   PACK OF 72 RETRO SPOT CAKE CASES, WHITE HANGING HEART T-LIGHT HOLDER -> 60 TEATIME FAIRY CAKE CASES | Confidence: 0.5639 | Lift: 9.2792
#   60 TEATIME FAIRY CAKE CASES, WHITE HANGING HEART T-LIGHT HOLDER -> PACK OF 72 RETRO SPOT CAKE CASES | Confidence: 0.6579 | Lift: 7.4909
# --------------------------------------------------
# Rule: ['RED 3 PIECE MINI DOTS CUTLERY SET', 'BLUE 3 PIECE MINI DOTS CUTLERY SET'] | Support: 0.0216
#   RED 3 PIECE MINI DOTS CUTLERY SET -> BLUE 3 PIECE MINI DOTS CUTLERY SET | Confidence: 0.6407 | Lift: 19.3505
#   BLUE 3 PIECE MINI DOTS CUTLERY SET -> RED 3 PIECE MINI DOTS CUTLERY SET | Confidence: 0.6524 | Lift: 19.3505
# --------------------------------------------------
# Rule: ['PACK OF 72 RETRO SPOT CAKE CASES', 'PACK OF 60 PINK PAISLEY CAKE CASES'] | Support: 0.0329
#   PACK OF 60 PINK PAISLEY CAKE CASES -> PACK OF 72 RETRO SPOT CAKE CASES | Confidence: 0.6520 | Lift: 7.4238
# --------------------------------------------------
# Rule: ['PINK 3 PIECE MINI DOTS CUTLERY SET', 'BLUE 3 PIECE MINI DOTS CUTLERY SET'] | Support: 0.0198
#   BLUE 3 PIECE MINI DOTS CUTLERY SET -> PINK 3 PIECE MINI DOTS CUTLERY SET | Confidence: 0.5976 | Lift: 19.6008
#   PINK 3 PIECE MINI DOTS CUTLERY SET -> BLUE 3 PIECE MINI DOTS CUTLERY SET | Confidence: 0.6490 | Lift: 19.6008
# --------------------------------------------------
# Rule: ['EDWARDIAN PARASOL NATURAL', 'EDWARDIAN PARASOL BLACK'] | Support: 0.0166
#   EDWARDIAN PARASOL BLACK -> EDWARDIAN PARASOL NATURAL | Confidence: 0.5000 | Lift: 19.5000
#   EDWARDIAN PARASOL NATURAL -> EDWARDIAN PARASOL BLACK | Confidence: 0.6457 | Lift: 19.5000
# --------------------------------------------------
# Rule: ['RED SPOTTY CHARLOTTE BAG', 'STRAWBERRY CHARLOTTE BAG'] | Support: 0.0172
#   STRAWBERRY CHARLOTTE BAG -> RED SPOTTY CHARLOTTE BAG | Confidence: 0.6439 | Lift: 15.1158
# --------------------------------------------------
# Rule: ['60 TEATIME FAIRY CAKE CASES', 'PACK OF 60 DINOSAUR CAKE CASES'] | Support: 0.0214
#   PACK OF 60 DINOSAUR CAKE CASES -> 60 TEATIME FAIRY CAKE CASES | Confidence: 0.6386 | Lift: 10.5075
# --------------------------------------------------
# Rule: ['VINTAGE HEADS AND TAILS CARD GAME ', 'VINTAGE SNAP CARDS'] | Support: 0.0236
#   VINTAGE SNAP CARDS -> VINTAGE HEADS AND TAILS CARD GAME  | Confidence: 0.5598 | Lift: 15.0692
#   VINTAGE HEADS AND TAILS CARD GAME  -> VINTAGE SNAP CARDS | Confidence: 0.6359 | Lift: 15.0692
# --------------------------------------------------
# Rule: ['BATH BUILDING BLOCK WORD', 'HOME BUILDING BLOCK WORD'] | Support: 0.0188
#   BATH BUILDING BLOCK WORD -> HOME BUILDING BLOCK WORD | Confidence: 0.6327 | Lift: 9.4383
# --------------------------------------------------
# Rule: ['WOODEN PICTURE FRAME WHITE FINISH', 'WOODEN FRAME ANTIQUE WHITE '] | Support: 0.0208
#   WOODEN PICTURE FRAME WHITE FINISH -> WOODEN FRAME ANTIQUE WHITE  | Confidence: 0.6319 | Lift: 10.2281
# --------------------------------------------------
# Rule: ['SINGLE HEART ZINC T-LIGHT HOLDER', 'HANGING HEART ZINC T-LIGHT HOLDER'] | Support: 0.0216
#   SINGLE HEART ZINC T-LIGHT HOLDER -> HANGING HEART ZINC T-LIGHT HOLDER | Confidence: 0.6294 | Lift: 15.0603
#   HANGING HEART ZINC T-LIGHT HOLDER -> SINGLE HEART ZINC T-LIGHT HOLDER | Confidence: 0.5169 | Lift: 15.0603
# --------------------------------------------------
# Rule: ['FAWN BLUE HOT WATER BOTTLE', 'MUSHROOM BLUE HOT WATER BOTTLE'] | Support: 0.0162
#   MUSHROOM BLUE HOT WATER BOTTLE -> FAWN BLUE HOT WATER BOTTLE | Confidence: 0.6250 | Lift: 15.9568
# --------------------------------------------------
# Rule: ['CHARLIE+LOLA PINK HOT WATER BOTTLE', 'CHARLIE + LOLA RED HOT WATER BOTTLE'] | Support: 0.0153
#   CHARLIE+LOLA PINK HOT WATER BOTTLE -> CHARLIE + LOLA RED HOT WATER BOTTLE | Confidence: 0.5672 | Lift: 23.0259
#   CHARLIE + LOLA RED HOT WATER BOTTLE -> CHARLIE+LOLA PINK HOT WATER BOTTLE | Confidence: 0.6230 | Lift: 23.0259
# --------------------------------------------------
# Rule: ['WHITE CHERRY LIGHTS', 'PINK CHERRY LIGHTS'] | Support: 0.0254
#   PINK CHERRY LIGHTS -> WHITE CHERRY LIGHTS | Confidence: 0.6176 | Lift: 11.4149
# --------------------------------------------------
# Rule: ['CHARLOTTE BAG , PINK/WHITE SPOTS', 'RED SPOTTY CHARLOTTE BAG'] | Support: 0.0246
#   RED SPOTTY CHARLOTTE BAG -> CHARLOTTE BAG , PINK/WHITE SPOTS | Confidence: 0.5782 | Lift: 14.4637
#   CHARLOTTE BAG , PINK/WHITE SPOTS -> RED SPOTTY CHARLOTTE BAG | Confidence: 0.6162 | Lift: 14.4637
# --------------------------------------------------
# Rule: ['JUMBO BAG SCANDINAVIAN PAISLEY', 'JUMBO BAG PINK VINTAGE PAISLEY'] | Support: 0.0172
#   JUMBO BAG SCANDINAVIAN PAISLEY -> JUMBO BAG PINK VINTAGE PAISLEY | Confidence: 0.6159 | Lift: 17.3339
# --------------------------------------------------
# Rule: ['60 TEATIME FAIRY CAKE CASES', 'PACK OF 72 RETRO SPOT CAKE CASES'] | Support: 0.0371
#   60 TEATIME FAIRY CAKE CASES -> PACK OF 72 RETRO SPOT CAKE CASES | Confidence: 0.6113 | Lift: 6.9603
# --------------------------------------------------
# Rule: ['SET OF 72 RETRO SPOT PAPER  DOILIES', 'PACK OF 72 RETRO SPOT CAKE CASES'] | Support: 0.0198
#   SET OF 72 RETRO SPOT PAPER  DOILIES -> PACK OF 72 RETRO SPOT CAKE CASES | Confidence: 0.6087 | Lift: 6.9307
# --------------------------------------------------
# Rule: ['JUMBO BAG RED WHITE SPOTTY ', 'JUMBO BAG OWLS'] | Support: 0.0184
#   JUMBO BAG OWLS -> JUMBO BAG RED WHITE SPOTTY  | Confidence: 0.6026 | Lift: 7.2450
# --------------------------------------------------
# Rule: ['JUMBO BAG RED WHITE SPOTTY ', 'JUMBO BAG WOODLAND ANIMALS'] | Support: 0.0164
#   JUMBO BAG WOODLAND ANIMALS -> JUMBO BAG RED WHITE SPOTTY  | Confidence: 0.5956 | Lift: 7.1601
# --------------------------------------------------
# Rule: ['PACK OF 60 MUSHROOM CAKE CASES', 'PACK OF 72 RETRO SPOT CAKE CASES'] | Support: 0.0157
#   PACK OF 60 MUSHROOM CAKE CASES -> PACK OF 72 RETRO SPOT CAKE CASES | Confidence: 0.5954 | Lift: 6.7796
# --------------------------------------------------
# Rule: ['WOODEN PICTURE FRAME WHITE FINISH', 'WHITE HANGING HEART T-LIGHT HOLDER'] | Support: 0.0196
#   WOODEN PICTURE FRAME WHITE FINISH -> WHITE HANGING HEART T-LIGHT HOLDER | Confidence: 0.5951 | Lift: 3.4353
# --------------------------------------------------
# Rule: ['WOOD 2 DRAWER CABINET WHITE FINISH', 'WHITE HANGING HEART T-LIGHT HOLDER'] | Support: 0.0196
#   WOOD 2 DRAWER CABINET WHITE FINISH -> WHITE HANGING HEART T-LIGHT HOLDER | Confidence: 0.5915 | Lift: 3.4144
# --------------------------------------------------
# Rule: ['ROUND SNACK BOXES SET OF 4 FRUITS ', 'ROUND SNACK BOXES SET OF4 WOODLAND '] | Support: 0.0153
#   ROUND SNACK BOXES SET OF 4 FRUITS  -> ROUND SNACK BOXES SET OF4 WOODLAND  | Confidence: 0.5891 | Lift: 16.4861
# --------------------------------------------------
# Rule: ['PINK BLUE FELT CRAFT TRINKET BOX', 'PINK CREAM FELT CRAFT TRINKET BOX '] | Support: 0.0194
#   PINK BLUE FELT CRAFT TRINKET BOX -> PINK CREAM FELT CRAFT TRINKET BOX  | Confidence: 0.5890 | Lift: 17.4677
#   PINK CREAM FELT CRAFT TRINKET BOX  -> PINK BLUE FELT CRAFT TRINKET BOX | Confidence: 0.5749 | Lift: 17.4677
# --------------------------------------------------
# Rule: ['RETRO SPOT LARGE MILK JUG', 'RETRO SPOT SMALL MILK JUG'] | Support: 0.0212
#   RETRO SPOT LARGE MILK JUG -> RETRO SPOT SMALL MILK JUG | Confidence: 0.5866 | Lift: 12.3110
# --------------------------------------------------
# Rule: ['SMALL HEART MEASURING SPOONS', 'LARGE HEART MEASURING SPOONS'] | Support: 0.0196
#   LARGE HEART MEASURING SPOONS -> SMALL HEART MEASURING SPOONS | Confidence: 0.5607 | Lift: 16.7296
#   SMALL HEART MEASURING SPOONS -> LARGE HEART MEASURING SPOONS | Confidence: 0.5843 | Lift: 16.7296
# --------------------------------------------------
# Rule: ['METAL 4 HOOK HANGER FRENCH CHATEAU', 'WHITE HANGING HEART T-LIGHT HOLDER'] | Support: 0.0186
#   METAL 4 HOOK HANGER FRENCH CHATEAU -> WHITE HANGING HEART T-LIGHT HOLDER | Confidence: 0.5823 | Lift: 3.3613
# --------------------------------------------------
# Rule: ['WOOD S/3 CABINET ANT WHITE FINISH', 'WOOD 2 DRAWER CABINET WHITE FINISH'] | Support: 0.0192
#   WOOD 2 DRAWER CABINET WHITE FINISH -> WOOD S/3 CABINET ANT WHITE FINISH | Confidence: 0.5793 | Lift: 14.6383
# --------------------------------------------------
# Rule: ['LUNCH BAG SUKI  DESIGN ', 'LUNCH BAG SPACEBOY DESIGN '] | Support: 0.0176
#   LUNCH BAG SPACEBOY DESIGN  -> LUNCH BAG SUKI  DESIGN  | Confidence: 0.5541 | Lift: 18.0569
#   LUNCH BAG SUKI  DESIGN  -> LUNCH BAG SPACEBOY DESIGN  | Confidence: 0.5724 | Lift: 18.0569
# --------------------------------------------------
# Rule: ['LUNCH BAG RED SPOTTY', 'LUNCH BAG WOODLAND'] | Support: 0.0208
#   LUNCH BAG WOODLAND -> LUNCH BAG RED SPOTTY | Confidence: 0.5722 | Lift: 9.3848
# --------------------------------------------------
# Rule: ['HOT WATER BOTTLE TEA AND SYMPATHY', 'CHOCOLATE HOT WATER BOTTLE'] | Support: 0.0307
#   CHOCOLATE HOT WATER BOTTLE -> HOT WATER BOTTLE TEA AND SYMPATHY | Confidence: 0.5693 | Lift: 8.2689
# --------------------------------------------------
# Rule: ['WOODLAND CHARLOTTE BAG', 'RED SPOTTY CHARLOTTE BAG'] | Support: 0.0184
#   WOODLAND CHARLOTTE BAG -> RED SPOTTY CHARLOTTE BAG | Confidence: 0.5687 | Lift: 13.3508
# --------------------------------------------------
# Rule: ['JUMBO BAG RED WHITE SPOTTY ', 'JUMBO BAG PINK VINTAGE PAISLEY'] | Support: 0.0202
#   JUMBO BAG PINK VINTAGE PAISLEY -> JUMBO BAG RED WHITE SPOTTY  | Confidence: 0.5682 | Lift: 6.8306
# --------------------------------------------------
# Rule: ['PACK OF 72 RETRO SPOT CAKE CASES', '72 SWEETHEART FAIRY CAKE CASES'] | Support: 0.0311
#   72 SWEETHEART FAIRY CAKE CASES -> PACK OF 72 RETRO SPOT CAKE CASES | Confidence: 0.5641 | Lift: 6.4230
# --------------------------------------------------
# Rule: ['RED 3 PIECE MINI DOTS CUTLERY SET', 'PINK 3 PIECE MINI DOTS CUTLERY SET'] | Support: 0.0170
#   RED 3 PIECE MINI DOTS CUTLERY SET -> PINK 3 PIECE MINI DOTS CUTLERY SET | Confidence: 0.5030 | Lift: 16.4989
#   PINK 3 PIECE MINI DOTS CUTLERY SET -> RED 3 PIECE MINI DOTS CUTLERY SET | Confidence: 0.5563 | Lift: 16.4989
# --------------------------------------------------
# Rule: ['WHITE HANGING HEART T-LIGHT HOLDER', 'CREAM HEART CARD HOLDER'] | Support: 0.0333
#   CREAM HEART CARD HOLDER -> WHITE HANGING HEART T-LIGHT HOLDER | Confidence: 0.5537 | Lift: 3.1963
# --------------------------------------------------
# Rule: ['WOOD S/3 CABINET ANT WHITE FINISH', 'WOODEN FRAME ANTIQUE WHITE '] | Support: 0.0218
#   WOOD S/3 CABINET ANT WHITE FINISH -> WOODEN FRAME ANTIQUE WHITE  | Confidence: 0.5510 | Lift: 8.9190
# --------------------------------------------------
# Rule: ['LUNCH BAG RED SPOTTY', 'LUNCH BAG CARS BLUE'] | Support: 0.0206
#   LUNCH BAG CARS BLUE -> LUNCH BAG RED SPOTTY | Confidence: 0.5368 | Lift: 8.8046
# --------------------------------------------------
# Rule: ['PACK OF 60 DINOSAUR CAKE CASES', 'PACK OF 60 PINK PAISLEY CAKE CASES'] | Support: 0.0180
#   PACK OF 60 DINOSAUR CAKE CASES -> PACK OF 60 PINK PAISLEY CAKE CASES | Confidence: 0.5361 | Lift: 10.6221
# --------------------------------------------------
# Rule: ['60 TEATIME FAIRY CAKE CASES', 'PACK OF 60 PINK PAISLEY CAKE CASES'] | Support: 0.0271
#   PACK OF 60 PINK PAISLEY CAKE CASES -> 60 TEATIME FAIRY CAKE CASES | Confidence: 0.5360 | Lift: 8.8200
# --------------------------------------------------
# Rule: ['LUNCH BAG RED SPOTTY', 'LUNCH BAG  BLACK SKULL.'] | Support: 0.0234
#   LUNCH BAG  BLACK SKULL. -> LUNCH BAG RED SPOTTY | Confidence: 0.5346 | Lift: 8.7672
# --------------------------------------------------
# Rule: ['JUMBO BAG RED WHITE SPOTTY ', 'JUMBO  BAG BAROQUE BLACK WHITE'] | Support: 0.0218
#   JUMBO  BAG BAROQUE BLACK WHITE -> JUMBO BAG RED WHITE SPOTTY  | Confidence: 0.5268 | Lift: 6.3335
# --------------------------------------------------
# Rule: ['RECYCLING BAG RETROSPOT ', 'TOY TIDY PINK RETROSPOT  '] | Support: 0.0151
#   RECYCLING BAG RETROSPOT  -> TOY TIDY PINK RETROSPOT   | Confidence: 0.5172 | Lift: 17.9154
#   TOY TIDY PINK RETROSPOT   -> RECYCLING BAG RETROSPOT  | Confidence: 0.5245 | Lift: 17.9154
# --------------------------------------------------
# Rule: ['CHARLOTTE BAG , PINK/WHITE SPOTS', 'CHARLOTTE BAG , SUKI DESIGN'] | Support: 0.0200
#   CHARLOTTE BAG , SUKI DESIGN -> CHARLOTTE BAG , PINK/WHITE SPOTS | Confidence: 0.5238 | Lift: 13.1032
#   CHARLOTTE BAG , PINK/WHITE SPOTS -> CHARLOTTE BAG , SUKI DESIGN | Confidence: 0.5000 | Lift: 13.1032
# --------------------------------------------------
# Rule: ['WOOD 2 DRAWER CABINET WHITE FINISH', 'WOODEN FRAME ANTIQUE WHITE '] | Support: 0.0172
#   WOOD 2 DRAWER CABINET WHITE FINISH -> WOODEN FRAME ANTIQUE WHITE  | Confidence: 0.5183 | Lift: 8.3892
# --------------------------------------------------
# Rule: ['WHITE HANGING HEART T-LIGHT HOLDER', 'HEART IVORY TRELLIS SMALL'] | Support: 0.0182
#   HEART IVORY TRELLIS SMALL -> WHITE HANGING HEART T-LIGHT HOLDER | Confidence: 0.5172 | Lift: 2.9859
# --------------------------------------------------
# Rule: ['WOOD S/3 CABINET ANT WHITE FINISH', 'WHITE HANGING HEART T-LIGHT HOLDER'] | Support: 0.0204
#   WOOD S/3 CABINET ANT WHITE FINISH -> WHITE HANGING HEART T-LIGHT HOLDER | Confidence: 0.5153 | Lift: 2.9747
# --------------------------------------------------
# Rule: ['WHITE HANGING HEART T-LIGHT HOLDER', 'WOODEN FRAME ANTIQUE WHITE '] | Support: 0.0317
#   WOODEN FRAME ANTIQUE WHITE  -> WHITE HANGING HEART T-LIGHT HOLDER | Confidence: 0.5131 | Lift: 2.9618
# --------------------------------------------------
# Rule: ['GIN + TONIC DIET METAL SIGN', 'LADIES & GENTLEMEN METAL SIGN'] | Support: 0.0153
#   LADIES & GENTLEMEN METAL SIGN -> GIN + TONIC DIET METAL SIGN | Confidence: 0.5101 | Lift: 9.7543
# --------------------------------------------------
# Rule: ['JUMBO STORAGE BAG SUKI', 'JUMBO BAG OWLS'] | Support: 0.0155
#   JUMBO BAG OWLS -> JUMBO STORAGE BAG SUKI | Confidence: 0.5099 | Lift: 9.6034
# --------------------------------------------------
# Rule: ['WOODLAND CHARLOTTE BAG', 'CHARLOTTE BAG , SUKI DESIGN'] | Support: 0.0164
#   WOODLAND CHARLOTTE BAG -> CHARLOTTE BAG , SUKI DESIGN | Confidence: 0.5063 | Lift: 13.2670
# --------------------------------------------------
# Rule: ['JUMBO BAG RED WHITE SPOTTY ', 'JUMBO STORAGE BAG SUKI'] | Support: 0.0269
#   JUMBO STORAGE BAG SUKI -> JUMBO BAG RED WHITE SPOTTY  | Confidence: 0.5057 | Lift: 6.0795
# --------------------------------------------------
# Rule: ['WOODLAND CHARLOTTE BAG', 'CHARLOTTE BAG , PINK/WHITE SPOTS'] | Support: 0.0162
#   WOODLAND CHARLOTTE BAG -> CHARLOTTE BAG , PINK/WHITE SPOTS | Confidence: 0.5000 | Lift: 12.5076
# --------------------------------------------------
# Rule: ['LOVE BUILDING BLOCK WORD', 'HOME BUILDING BLOCK WORD'] | Support: 0.0311
#   LOVE BUILDING BLOCK WORD -> HOME BUILDING BLOCK WORD | Confidence: 0.5000 | Lift: 7.4593
# --------------------------------------------------

# %% [markdown]
# ### Now we can check if some products are more likely to get bought at certain times in the day:

# %%
combined_transactions = df.groupby("Invoice").apply(
    lambda x: x.drop(columns="Invoice")["StockCode"].tolist() + [x["TimeOfDay"].iloc[0]]
).tolist()

# Run Apriori for Product-TimeOfDay category association
timing_rules = list(apriori(
    combined_transactions,
    min_support=0.02,
    min_confidence=0.5,
    min_lift=1.1,
    min_length=2
))

# Filter out rules containing multiple time categories
filtered_timing_rules = []
for rule in timing_rules:
    items = list(rule.items)

    # Ensure TimeCategory is not repeated
    time_categories = [item for item in items if item in ["Morning", "Afternoon", "Evening", "Night"]]

    if len(time_categories) == 1:  # Only allow one time-related element
        filtered_timing_rules.append(rule)

display_association_rules(filtered_timing_rules, stockcode_to_description)
# Out:
# /tmp/ipykernel_20121/3726890584.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   combined_transactions = df.groupby("Invoice").apply(
# --- ASSOCIATION RULES (Sorted by Confidence) ---
#
# Rule: ['Afternoon', 'VINTAGE UNION JACK BUNTING'] | Support: 0.0256
#   VINTAGE UNION JACK BUNTING -> Afternoon | Confidence: 0.7840 | Lift: 1.1871
# --------------------------------------------------
# Rule: ['HAND OVER THE CHOCOLATE   SIGN ', 'Afternoon'] | Support: 0.0275
#   HAND OVER THE CHOCOLATE   SIGN  -> Afternoon | Confidence: 0.7771 | Lift: 1.1768
# --------------------------------------------------
# Rule: ['Afternoon', 'FELTCRAFT BUTTERFLY HEARTS'] | Support: 0.0293
#   FELTCRAFT BUTTERFLY HEARTS -> Afternoon | Confidence: 0.7632 | Lift: 1.1556
# --------------------------------------------------
# Rule: ['Afternoon', 'RED HANGING HEART T-LIGHT HOLDER', 'WHITE HANGING HEART T-LIGHT HOLDER'] | Support: 0.0325
#   RED HANGING HEART T-LIGHT HOLDER -> Afternoon, WHITE HANGING HEART T-LIGHT HOLDER | Confidence: 0.5127 | Lift: 4.4790
#   Afternoon, RED HANGING HEART T-LIGHT HOLDER -> WHITE HANGING HEART T-LIGHT HOLDER | Confidence: 0.7630 | Lift: 4.4048
# --------------------------------------------------
# Rule: ['Afternoon', 'JUMBO BAG STRAWBERRY'] | Support: 0.0281
#   JUMBO BAG STRAWBERRY -> Afternoon | Confidence: 0.7596 | Lift: 1.1501
# --------------------------------------------------
# Rule: ['Afternoon', 'HOT BATHS METAL SIGN'] | Support: 0.0226
#   HOT BATHS METAL SIGN -> Afternoon | Confidence: 0.7568 | Lift: 1.1459
# --------------------------------------------------
# Rule: ['Afternoon', 'POTTING SHED TEA MUG'] | Support: 0.0248
#   POTTING SHED TEA MUG -> Afternoon | Confidence: 0.7500 | Lift: 1.1357
# --------------------------------------------------
# Rule: ['Afternoon', 'PACK OF 72 SKULL CAKE CASES'] | Support: 0.0258
#   PACK OF 72 SKULL CAKE CASES -> Afternoon | Confidence: 0.7485 | Lift: 1.1334
# --------------------------------------------------
# Rule: ['Afternoon', 'WOODEN PICTURE FRAME WHITE FINISH'] | Support: 0.0246
#   WOODEN PICTURE FRAME WHITE FINISH -> Afternoon | Confidence: 0.7485 | Lift: 1.1333
# --------------------------------------------------
# Rule: ['Afternoon', 'WOODEN FRAME ANTIQUE WHITE '] | Support: 0.0462
#   WOODEN FRAME ANTIQUE WHITE  -> Afternoon | Confidence: 0.7484 | Lift: 1.1332
# --------------------------------------------------
# Rule: ['Afternoon', 'REX CASH+CARRY JUMBO SHOPPER'] | Support: 0.0361
#   REX CASH+CARRY JUMBO SHOPPER -> Afternoon | Confidence: 0.7458 | Lift: 1.1294
# --------------------------------------------------
# Rule: ['No description available', 'Afternoon'] | Support: 0.0228
#   No description available -> Afternoon | Confidence: 0.7434 | Lift: 1.1257
# --------------------------------------------------
# Rule: ['RETRO SPOT SUGAR JAM BOWL', 'Afternoon'] | Support: 0.0238
#   RETRO SPOT SUGAR JAM BOWL -> Afternoon | Confidence: 0.7421 | Lift: 1.1238
# --------------------------------------------------
# Rule: ['BEWARE OF THE CAT METAL SIGN ', 'Afternoon'] | Support: 0.0220
#   BEWARE OF THE CAT METAL SIGN  -> Afternoon | Confidence: 0.7415 | Lift: 1.1228
# --------------------------------------------------
# Rule: ['Afternoon', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WOODEN FRAME ANTIQUE WHITE '] | Support: 0.0234
#   WHITE HANGING HEART T-LIGHT HOLDER, WOODEN FRAME ANTIQUE WHITE  -> Afternoon | Confidence: 0.7389 | Lift: 1.1188
#   Afternoon, WOODEN FRAME ANTIQUE WHITE  -> WHITE HANGING HEART T-LIGHT HOLDER | Confidence: 0.5066 | Lift: 2.9242
# --------------------------------------------------
# Rule: ['FELTCRAFT 6 FLOWER FRIENDS', 'Afternoon'] | Support: 0.0305
#   FELTCRAFT 6 FLOWER FRIENDS -> Afternoon | Confidence: 0.7366 | Lift: 1.1153
# --------------------------------------------------
# Rule: ['Afternoon', 'JUMBO BAG WOODLAND ANIMALS'] | Support: 0.0202
#   JUMBO BAG WOODLAND ANIMALS -> Afternoon | Confidence: 0.7353 | Lift: 1.1134
# --------------------------------------------------
# Rule: ['JUMBO BAG SCANDINAVIAN PAISLEY', 'Afternoon'] | Support: 0.0204
#   JUMBO BAG SCANDINAVIAN PAISLEY -> Afternoon | Confidence: 0.7319 | Lift: 1.1082
# --------------------------------------------------
# Rule: ['Afternoon', 'KNITTED UNION FLAG HOT WATER BOTTLE'] | Support: 0.0307
#   KNITTED UNION FLAG HOT WATER BOTTLE -> Afternoon | Confidence: 0.7308 | Lift: 1.1065
# --------------------------------------------------
# Rule: ['RED SPOTTY BISCUIT TIN', 'Afternoon'] | Support: 0.0228
#   RED SPOTTY BISCUIT TIN -> Afternoon | Confidence: 0.7290 | Lift: 1.1039
# --------------------------------------------------
# Rule: ['Afternoon', 'PACK OF 72 RETRO SPOT CAKE CASES', 'PACK OF 60 PINK PAISLEY CAKE CASES'] | Support: 0.0204
#   Afternoon, PACK OF 60 PINK PAISLEY CAKE CASES -> PACK OF 72 RETRO SPOT CAKE CASES | Confidence: 0.6196 | Lift: 7.0553
# --------------------------------------------------
# Rule: ['Afternoon', '60 TEATIME FAIRY CAKE CASES', 'PACK OF 72 RETRO SPOT CAKE CASES'] | Support: 0.0232
#   Afternoon, 60 TEATIME FAIRY CAKE CASES -> PACK OF 72 RETRO SPOT CAKE CASES | Confidence: 0.6117 | Lift: 6.9650
# --------------------------------------------------
# Rule: ['Afternoon', 'PACK OF 72 RETRO SPOT CAKE CASES', '72 SWEETHEART FAIRY CAKE CASES'] | Support: 0.0204
#   Afternoon, 72 SWEETHEART FAIRY CAKE CASES -> PACK OF 72 RETRO SPOT CAKE CASES | Confidence: 0.5706 | Lift: 6.4972
# --------------------------------------------------
# Rule: ['Afternoon', 'WHITE HANGING HEART T-LIGHT HOLDER', 'CREAM HEART CARD HOLDER'] | Support: 0.0240
#   Afternoon, CREAM HEART CARD HOLDER -> WHITE HANGING HEART T-LIGHT HOLDER | Confidence: 0.5535 | Lift: 3.1951
# --------------------------------------------------
# Rule: ['Afternoon', 'HOT WATER BOTTLE TEA AND SYMPATHY', 'CHOCOLATE HOT WATER BOTTLE'] | Support: 0.0202
#   Afternoon, CHOCOLATE HOT WATER BOTTLE -> HOT WATER BOTTLE TEA AND SYMPATHY | Confidence: 0.5405 | Lift: 7.8513
# --------------------------------------------------

# %% [markdown]
# ### Instead of looking at the products, we can also look at customers and check if there are any associations with the price of the products they bought.

# %%
combined_transactions = df.dropna(subset=["Customer ID", "PriceCategory"]).apply(
    lambda x: [str(x["Customer ID"]), x["PriceCategory"]], axis=1
).tolist()

# Run Apriori for customer-price category association
customer_rules = list(apriori(
    combined_transactions,
    min_support=0.0005,
    min_confidence=0.5,
    min_lift=1.1,
    min_length=2
))

# Filter out rules between price categories only (keep customer-price links)
filtered_customer_rules = []
for rule in customer_rules:
    items = list(rule.items)

    # Ensure only one price category is present in each rule
    price_categories = [item for item in items if item in ["Cheap", "Mid-Range", "Expensive"]]

    if len(price_categories) == 1:
        filtered_customer_rules.append(rule)

display_association_rules(filtered_customer_rules)
# Out:
# --- ASSOCIATION RULES (Sorted by Confidence) ---
#
# Rule: ['17589.0', 'Cheap'] | Support: 0.0010
#   17589.0 -> Cheap | Confidence: 0.7724 | Lift: 2.1316
# --------------------------------------------------
# Rule: ['13542.0', 'Expensive'] | Support: 0.0005
#   13542.0 -> Expensive | Confidence: 0.7564 | Lift: 2.5695
# --------------------------------------------------
# Rule: ['14286.0', 'Cheap'] | Support: 0.0009
#   14286.0 -> Cheap | Confidence: 0.7537 | Lift: 2.0801
# --------------------------------------------------
# Rule: ['Cheap', '14298.0'] | Support: 0.0013
#   14298.0 -> Cheap | Confidence: 0.7381 | Lift: 2.0369
# --------------------------------------------------
# Rule: ['Cheap', '15013.0'] | Support: 0.0007
#   15013.0 -> Cheap | Confidence: 0.7304 | Lift: 2.0158
# --------------------------------------------------
# Rule: ['Cheap', '13694.0'] | Support: 0.0029
#   13694.0 -> Cheap | Confidence: 0.7296 | Lift: 2.0135
# --------------------------------------------------
# Rule: ['Cheap', '12867.0'] | Support: 0.0008
#   12867.0 -> Cheap | Confidence: 0.7109 | Lift: 1.9620
# --------------------------------------------------
# Rule: ['16960.0', 'Cheap'] | Support: 0.0007
#   16960.0 -> Cheap | Confidence: 0.7069 | Lift: 1.9508
# --------------------------------------------------
# Rule: ['13975.0', 'Cheap'] | Support: 0.0007
#   13975.0 -> Cheap | Confidence: 0.7064 | Lift: 1.9495
# --------------------------------------------------
# Rule: ['Cheap', '17449.0'] | Support: 0.0007
#   17449.0 -> Cheap | Confidence: 0.6903 | Lift: 1.9049
# --------------------------------------------------
# Rule: ['Cheap', '15358.0'] | Support: 0.0007
#   15358.0 -> Cheap | Confidence: 0.6885 | Lift: 1.9001
# --------------------------------------------------
# Rule: ['Cheap', '17861.0'] | Support: 0.0013
#   17861.0 -> Cheap | Confidence: 0.6820 | Lift: 1.8822
# --------------------------------------------------
# Rule: ['17160.0', 'Cheap'] | Support: 0.0006
#   17160.0 -> Cheap | Confidence: 0.6786 | Lift: 1.8727
# --------------------------------------------------
# Rule: ['Cheap', '14686.0'] | Support: 0.0006
#   14686.0 -> Cheap | Confidence: 0.6765 | Lift: 1.8669
# --------------------------------------------------
# Rule: ['Cheap', '13557.0'] | Support: 0.0005
#   13557.0 -> Cheap | Confidence: 0.6629 | Lift: 1.8295
# --------------------------------------------------
# Rule: ['Cheap', '16710.0'] | Support: 0.0010
#   16710.0 -> Cheap | Confidence: 0.6629 | Lift: 1.8295
# --------------------------------------------------
# Rule: ['Cheap', '15601.0'] | Support: 0.0011
#   15601.0 -> Cheap | Confidence: 0.6562 | Lift: 1.8111
# --------------------------------------------------
# Rule: ['Cheap', '15544.0'] | Support: 0.0007
#   15544.0 -> Cheap | Confidence: 0.6555 | Lift: 1.8089
# --------------------------------------------------
# Rule: ['Cheap', '13214.0'] | Support: 0.0006
#   13214.0 -> Cheap | Confidence: 0.6435 | Lift: 1.7758
# --------------------------------------------------
# Rule: ['Cheap', '12437.0'] | Support: 0.0009
#   12437.0 -> Cheap | Confidence: 0.6391 | Lift: 1.7636
# --------------------------------------------------
# Rule: ['Cheap', '14159.0'] | Support: 0.0010
#   14159.0 -> Cheap | Confidence: 0.6378 | Lift: 1.7603
# --------------------------------------------------
# Rule: ['Cheap', '15917.0'] | Support: 0.0007
#   15917.0 -> Cheap | Confidence: 0.6364 | Lift: 1.7562
# --------------------------------------------------
# Rule: ['Cheap', '13206.0'] | Support: 0.0019
#   13206.0 -> Cheap | Confidence: 0.6303 | Lift: 1.7393
# --------------------------------------------------
# Rule: ['Cheap', '16940.0'] | Support: 0.0006
#   16940.0 -> Cheap | Confidence: 0.6250 | Lift: 1.7248
# --------------------------------------------------
# Rule: ['Cheap', '13081.0'] | Support: 0.0024
#   13081.0 -> Cheap | Confidence: 0.6119 | Lift: 1.6888
# --------------------------------------------------
# Rule: ['Cheap', '15093.0'] | Support: 0.0005
#   15093.0 -> Cheap | Confidence: 0.6117 | Lift: 1.6880
# --------------------------------------------------
# Rule: ['Cheap', '15514.0'] | Support: 0.0005
#   15514.0 -> Cheap | Confidence: 0.6117 | Lift: 1.6880
# --------------------------------------------------
# Rule: ['Cheap', '14869.0'] | Support: 0.0006
#   14869.0 -> Cheap | Confidence: 0.6080 | Lift: 1.6779
# --------------------------------------------------
# Rule: ['Cheap', '17884.0'] | Support: 0.0007
#   17884.0 -> Cheap | Confidence: 0.6014 | Lift: 1.6598
# --------------------------------------------------
# Rule: ['Cheap', '15003.0'] | Support: 0.0012
#   15003.0 -> Cheap | Confidence: 0.6009 | Lift: 1.6583
# --------------------------------------------------
# Rule: ['Cheap', '17511.0'] | Support: 0.0010
#   17511.0 -> Cheap | Confidence: 0.5990 | Lift: 1.6530
# --------------------------------------------------
# Rule: ['Cheap', '14646.0'] | Support: 0.0019
#   14646.0 -> Cheap | Confidence: 0.5916 | Lift: 1.6327
# --------------------------------------------------
# Rule: ['Cheap', '12531.0'] | Support: 0.0006
#   12531.0 -> Cheap | Confidence: 0.5909 | Lift: 1.6307
# --------------------------------------------------
# Rule: ['Mid-Range', '17913.0'] | Support: 0.0005
#   17913.0 -> Mid-Range | Confidence: 0.5905 | Lift: 1.7202
# --------------------------------------------------
# Rule: ['Cheap', '16795.0'] | Support: 0.0006
#   16795.0 -> Cheap | Confidence: 0.5897 | Lift: 1.6275
# --------------------------------------------------
# Rule: ['Cheap', '14769.0'] | Support: 0.0006
#   14769.0 -> Cheap | Confidence: 0.5862 | Lift: 1.6178
# --------------------------------------------------
# Rule: ['Cheap', '12921.0'] | Support: 0.0007
#   12921.0 -> Cheap | Confidence: 0.5839 | Lift: 1.6114
# --------------------------------------------------
# Rule: ['Cheap', '14546.0'] | Support: 0.0007
#   14546.0 -> Cheap | Confidence: 0.5822 | Lift: 1.6067
# --------------------------------------------------
# Rule: ['17969.0', 'Expensive'] | Support: 0.0006
#   17969.0 -> Expensive | Confidence: 0.5812 | Lift: 1.9743
# --------------------------------------------------
# Rule: ['Cheap', '16461.0'] | Support: 0.0007
#   16461.0 -> Cheap | Confidence: 0.5755 | Lift: 1.5883
# --------------------------------------------------
# Rule: ['Cheap', '12472.0'] | Support: 0.0007
#   12472.0 -> Cheap | Confidence: 0.5733 | Lift: 1.5822
# --------------------------------------------------
# Rule: ['Cheap', '14648.0'] | Support: 0.0006
#   14648.0 -> Cheap | Confidence: 0.5714 | Lift: 1.5770
# --------------------------------------------------
# Rule: ['Cheap', '16595.0'] | Support: 0.0006
#   16595.0 -> Cheap | Confidence: 0.5659 | Lift: 1.5617
# --------------------------------------------------
# Rule: ['Cheap', '15061.0'] | Support: 0.0006
#   15061.0 -> Cheap | Confidence: 0.5656 | Lift: 1.5608
# --------------------------------------------------
# Rule: ['Cheap', '12748.0'] | Support: 0.0022
#   12748.0 -> Cheap | Confidence: 0.5647 | Lift: 1.5585
# --------------------------------------------------
# Rule: ['Cheap', '15984.0'] | Support: 0.0006
#   15984.0 -> Cheap | Confidence: 0.5615 | Lift: 1.5497
# --------------------------------------------------
# Rule: ['Cheap', '13178.0'] | Support: 0.0008
#   13178.0 -> Cheap | Confidence: 0.5562 | Lift: 1.5350
# --------------------------------------------------
# Rule: ['16393.0', 'Cheap'] | Support: 0.0007
#   16393.0 -> Cheap | Confidence: 0.5548 | Lift: 1.5312
# --------------------------------------------------
# Rule: ['Cheap', '14081.0'] | Support: 0.0022
#   14081.0 -> Cheap | Confidence: 0.5510 | Lift: 1.5205
# --------------------------------------------------
# Rule: ['Cheap', '15498.0'] | Support: 0.0005
#   15498.0 -> Cheap | Confidence: 0.5505 | Lift: 1.5191
# --------------------------------------------------
# Rule: ['Cheap', '17576.0'] | Support: 0.0007
#   17576.0 -> Cheap | Confidence: 0.5455 | Lift: 1.5053
# --------------------------------------------------
# Rule: ['16409.0', 'Cheap'] | Support: 0.0007
#   16409.0 -> Cheap | Confidence: 0.5321 | Lift: 1.4683
# --------------------------------------------------
# Rule: ['Cheap', '16986.0'] | Support: 0.0007
#   16986.0 -> Cheap | Confidence: 0.5287 | Lift: 1.4590
# --------------------------------------------------
# Rule: ['Cheap', '12681.0'] | Support: 0.0008
#   12681.0 -> Cheap | Confidence: 0.5257 | Lift: 1.4508
# --------------------------------------------------
# Rule: ['Cheap', '13004.0'] | Support: 0.0006
#   13004.0 -> Cheap | Confidence: 0.5245 | Lift: 1.4474
# --------------------------------------------------
# Rule: ['Cheap', '15581.0'] | Support: 0.0009
#   15581.0 -> Cheap | Confidence: 0.5213 | Lift: 1.4387
# --------------------------------------------------
# Rule: ['15044.0', 'Expensive'] | Support: 0.0008
#   15044.0 -> Expensive | Confidence: 0.5103 | Lift: 1.7335
# --------------------------------------------------
# Rule: ['Cheap', '14896.0'] | Support: 0.0007
#   14896.0 -> Cheap | Confidence: 0.5098 | Lift: 1.4069
# --------------------------------------------------
# Rule: ['Cheap', '17625.0'] | Support: 0.0007
#   17625.0 -> Cheap | Confidence: 0.5093 | Lift: 1.4056
# --------------------------------------------------
# Rule: ['13089.0', 'Cheap'] | Support: 0.0014
#   13089.0 -> Cheap | Confidence: 0.5076 | Lift: 1.4008
# --------------------------------------------------
# Rule: ['Cheap', '13503.0'] | Support: 0.0006
#   13503.0 -> Cheap | Confidence: 0.5074 | Lift: 1.4002
# --------------------------------------------------
# Rule: ['Cheap', '16788.0'] | Support: 0.0005
#   16788.0 -> Cheap | Confidence: 0.5040 | Lift: 1.3909
# --------------------------------------------------
# Rule: ['Cheap', '17610.0'] | Support: 0.0006
#   17610.0 -> Cheap | Confidence: 0.5034 | Lift: 1.3891
# --------------------------------------------------
# Rule: ['Cheap', '17085.0'] | Support: 0.0007
#   17085.0 -> Cheap | Confidence: 0.5032 | Lift: 1.3888
# --------------------------------------------------
# Rule: ['Cheap', '14669.0'] | Support: 0.0008
#   14669.0 -> Cheap | Confidence: 0.5026 | Lift: 1.3871
# --------------------------------------------------
# Rule: ['14527.0', 'Expensive'] | Support: 0.0034
#   14527.0 -> Expensive | Confidence: 0.5006 | Lift: 1.7006
# --------------------------------------------------
# Rule: ['Cheap', '13093.0'] | Support: 0.0006
#   13093.0 -> Cheap | Confidence: 0.5000 | Lift: 1.3799
# --------------------------------------------------
# Rule: ['Cheap', '15862.0'] | Support: 0.0005
#   15862.0 -> Cheap | Confidence: 0.5000 | Lift: 1.3799
# --------------------------------------------------

# %% [markdown]
# ### Lastly, we can check if a high price relates to a low quantity and a low price indicates a high quantity (or ofcourse in the other way).

# %%
combined_transactions = df.dropna(subset=["QuantityCategory","PriceCategory"]).apply(
    lambda x: [x["QuantityCategory"], x["PriceCategory"]], axis=1
).tolist()

# Run Apriori for price-quantity category association
price_quantity_rules = list(apriori(
    combined_transactions,
    min_support=0.02,
    min_confidence=0.3,
    min_lift=1.1,
    min_length=2
))

# Filter out rules between price categories only (keep customer-price links)
filtered_price_quantity_rules = []
for rule in price_quantity_rules:
    items = list(rule.items)

    # Ensure only one price category is present in each rule
    price_categories = [item for item in items if item in ["Cheap", "Mid-Range", "Expensive"]]

    if len(price_categories) == 1:
        filtered_price_quantity_rules.append(rule)

display_association_rules(filtered_price_quantity_rules)
# Out:
# --- ASSOCIATION RULES (Sorted by Confidence) ---
#
# Rule: ['Expensive', 'Small'] | Support: 0.2017
#   Expensive -> Small | Confidence: 0.6851 | Lift: 1.4717
#   Small -> Expensive | Confidence: 0.4332 | Lift: 1.4717
# --------------------------------------------------
# Rule: ['Cheap', 'Large'] | Support: 0.1969
#   Cheap -> Large | Confidence: 0.5434 | Lift: 1.8632
#   Large -> Cheap | Confidence: 0.6752 | Lift: 1.8632
# --------------------------------------------------
# Rule: ['Medium', 'Mid-Range'] | Support: 0.1080
#   Medium -> Mid-Range | Confidence: 0.4447 | Lift: 1.2954
#   Mid-Range -> Medium | Confidence: 0.3145 | Lift: 1.2954
# --------------------------------------------------
